-- %%
-- Check table presence
SHOW TABLES;

-- Validate table schema and structure
DESCRIBE TABLE EXTENDED dim_products;

-- Verify record counts and basic data health
SELECT 
    COUNT(*) AS total_rows,
    COUNT(DISTINCT product_id) AS unique_products
FROM dim_products;
